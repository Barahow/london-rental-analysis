# %%
import pandas as pd 

# Load GCSE dataset
gcse_df = pd.read_excel("../data/GCSE results by sex.xlsx", sheet_name='2023-24',header=1)

gcse_df.head()

gcse_df= gcse_df.rename(columns={'Unnamed: 1':'Borough'})

# %%
gcse_df.head()
# Out:
#   Unnamed: 0                 Borough  \
# 0  E09000007                  Camden
# 1  E09000012                 Hackney
# 2  E09000013  Hammersmith and Fulham
# 3  E09000014                Haringey
# 4  E09000019               Islington
#
#    Number of pupils at the end of key stage 4  \
# 0                                      1605.0
# 1                                      2468.0
# 2                                      1528.0
# 3                                      2713.0
# 4                                      1450.0
#
#    Average Attainment 8 score per pupil  Average Progress 8 score per pupil  \
# 0                                  47.9                               -0.14
# 1                                  51.2                                0.51
# 2                                  55.9                                0.52
# 3                                  48.1                                0.30
# ...
